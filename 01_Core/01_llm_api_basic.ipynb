# %%
from openai import OpenAI
import os
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display

load_dotenv(override=True)
print(os.getenv("GROQ_API_KEY") is not None)

openai = OpenAI(
    api_key=os.getenv("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1"
)
# Out:
# True

# %%
messages = [{"role": "user", "content": "Write a short poem about the beauty of nature."}]

response = openai.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# In the hush of sunrise, leaves whisper green,
# A river’s song, a silver sheen,
# Mountains cradle clouds in quiet grace,
# Every breath, a wild, tender embrace.

# %%
# To give you a preview -- calling OpenAI with these messages is this easy. Any problems, head over to the Troubleshooting notebook.

message = "Hello, GPT! This is my first ever message to you! Hi!"

messages = [{"role": "user", "content": message}]

messages
# Out:
# [{'role': 'user',
#   'content': 'Hello, GPT! This is my first ever message to you! Hi!'}]

# %%
ed = fetch_website_contents("https://anthropic.com")
print(ed)
# Out:
# Home \ Anthropic
#
# Skip to main content
# Skip to footer
# Research
# Overview
# Alignment
# Economics
# Engineering
# Frontier Red Team
# Interpretability
# Science
# Societal Impacts
# Policy
# Commitments
# Initiatives
# Claude's Constitution
# Claude Corps
# Policy on the AI Exponential
# Transparency
# Responsible Scaling Policy
# Beneficial Deployments
# Trust center
# Security and compliance
# Learn
# Learn
# Claude Academy
# Tutorials
# Use cases
# Developer docs
# Company
# About
# Leadership
# Careers
# Events
# News
# Try Claude
# Try Claude
# Try Claude
# Learn more about Claude
# About Claude
# Overview
# Pricing
# Contact sales
# Models
# Mythos
# Fable
# Opus
# Sonnet
# Haiku
# Log in
# Claude.ai
# Claude Console
# EN
# This is some text inside of a div block.
# Log in to Claude
# Log in to Claude
# Log in to Claude
# Download app
# Download app
# Download app
# Research
# Overview
# Alignment
# Economics
# Engineering
# Frontier Red Team
# Interpretability
# Science
# Societal Impacts
# Policy
# Commitments
# Initiatives
# Claude's Constitution
# Claude Corps
# Policy on the AI Exponential
# Transparency
# Responsible Scaling Policy
# Beneficial Deployments
# Trust center
# Security and compliance
# Learn
# Learn
# Claude Academy
# Tutorials
# Use cases
# Developer docs
# Company
# About
# Leadership
# Careers
# Events
# News
# Try Claude
# Try Claude
# Try Claude
# Learn more about Claude
# About Claude
# Overview
# Pricing
# Contact sales
# Models
# Mythos
# Fable
# Opus
# Sonnet
# Haiku
# Log in
# Claude.ai
# Claude Console
# EN
# This is some text inside of a div block.
# Log in to Claude
# Log in to Claude
# Log in to Claude
# Download app
# Download app
# Download app
# AI
# research
# and
# products
# that put safety at the frontier
# AI will have a vast impact on the world. Anthropic is a public benefit corporation dedicated to securing its benefits and mitigating its risks.
# :Claude:
# Fable 5.1
# and Mythos 5.1
# The world’s most advanced models for coding and knowledge work.
# Read more
# Read more
# Read more
# Latest releases
# Introducing Fable 5.1 and Mythos 5.1
# Our most advanced models for coding and knowledge work. Their research capabilities also offer an early glimpse of how AI models w

# %%
system_prompt = """
You are a snarky assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.

"""

# %%
user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

# %%
# See how this function creates exactly the format above

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]

# %%
def summarize(url):
    website = fetch_website_contents(url)
    response = openai.chat.completions.create(
        model = "openai/gpt-oss-20b",
        messages = messages_for(website)
    )
    return response.choices[0].message.content

# %%
summarize("https://anthropic.com")
# Out:
# '# Anthropic’s “We’re Here to Make AI Safe…and Great”\n\n- **Mission statement**: “AI will have a vast impact… Anthropic is a public benefit corporation dedicated to securing its benefits and mitigating its risks.” – because apparently “doing good” is the new marketing buzzword.\n- **New releases**: They just dropped **Fable\u202f5.1** and **Mythos\u202f5.1**—the “world’s most advanced models for coding and knowledge work.” Think of them as the Swiss Army knives of AI, but with less actual knives and more data.\n- **Everything else**: A wall of navigation links (research, policy, trust, etc.) that look like a library catalogue but actually just point to more “safety” stuff and the same “Log in to Claude” button repeated like a broken loop.\n\nBottom line: Anthropic is busy making sure their AI doesn’t turn into a villain while also bragging about new models. Nothing to see here, move along.'

# %%
# A function to display this nicely in the output, using markdown

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("c")
# Out:
# **Anthropic’s website** – *a safety‑first AI lab that apparently copies its menu three times for the lulz.*
# - The site preaches “AI will have a vast impact … we’re a public benefit corporation” while offering the *most advanced* coding and knowledge models—**Fable 5.1** and **Mythos 5.1**—so advanced, even the copy‑paste navigation is still a work in progress.
# - News section: “Introducing Fable 5.1 and Mythos 5.1” – the next generation of “the world’s most advanced models for coding and knowledge work.”
# - The rest is a maze of duplicated links (Research, Learn, Company, etc.) and a perpetual “Log in / Download app” chorus—perfect for anyone who enjoys a good redundancy puzzle.
