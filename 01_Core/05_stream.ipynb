# %%
import os
from dotenv import load_dotenv
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
load_dotenv(override=True)
api_key = os.getenv('GROQ_API_KEY')

if api_key and api_key.startswith('gsk_') and len(api_key)>10:
  print("API key looks good so far")
else:
  print("There might be a problem with your API key? Please visit the troubleshooting notebook!")

MODEL = 'openai/gpt-oss-20b'
openai = OpenAI(
  api_key=os.getenv("GROQ_API_KEY"),
  base_url="https://api.groq.com/openai/v1"
)
# Out:
# API key looks good so far

# %%
system_prompt = """
You are funny story teller.
"""

# %%
user_prompt = """
tell me a story. anything and it must be funny and longer than 200 words. It should be a story and not a one liner.
"""

# %%
def stream_story():
  stream = openai.chat.completions.create(
    model=MODEL,
    messages=[
      {"role": "system", "content": system_prompt},
      {"role": "user", "content": user_prompt}
    ],
    stream=True
  )
  response_text = ""
  display_handle = display(Markdown(""), display_id=True)
  for chunk in stream:
    response_text += chunk.choices[0].delta.content or ""
    update_display(Markdown(response_text), display_id=display_handle.display_id)

# %%
stream_story()
# Out:
# **The Great Muffin Caper**
#
# In the sleepy town of Crumpetville, where the most exciting thing on the calendar was the annual “Pigeon Watching” festival, lived Harold, an unassuming baker with a questionable taste for adventure. Harold owned a tiny bakery called “Harold’s Half‑Baked” – a name that was actually a clever nod to the fact that his pastries were always halfway finished, never quite rising to greatness.
#
# One bright Monday, Harold decided he would finally try his hand at the town’s famed “Grand Bake-Off.” He set his sights on the coveted trophy: a shiny silver rolling pin that was rumored to grant the baker a lifetime supply of flour. The stakes were high, the crowd was skeptical, and Harold was, quite frankly, terrified. He had once baked a cake that accidentally turned the bakery into a confetti factory and the town’s mayor still hasn’t forgiven him for the “Great Sprinkle Incident” of 2019.
#
# ...
