# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import display, Markdown

# %%
load_dotenv(override=True)
print(os.getenv("GROQ_API_KEY") is not None)
print(os.getenv("GOOGLE_API_KEY") is not None)
# Out:
# True
# True

# %%
groq_client = OpenAI(api_key=os.getenv("GROQ_API_KEY"), base_url="https://api.groq.com/openai/v1")
google_client = OpenAI(api_key=os.getenv("GOOGLE_API_KEY"), base_url="https://generativelanguage.googleapis.com/v1beta/openai/")

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" if both of you choose this, you each win $1,000.
Defect: Choose "Steal" if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
  {"role": "user", "content": dilemma_prompt}
]

# %%
response_groq = groq_client.chat.completions.create(
  model="openai/gpt-oss-20b",
  messages=dilemma,
)
display(Markdown(response_groq.choices[0].message.content))
# Out:
# Steal.

# %%
gemini_response = google_client.chat.completions.create(
  model="gemini-3.1-flash-lite",
  messages=dilemma,
)
display(Markdown(gemini_response.choices[0].message.content))
# Out:
# In this scenario, I choose to **Share**.
#
# Here is my reasoning:
#
# While the "Steal" option offers a higher potential payout if I assume my partner will cooperate, it also introduces the risk of getting nothing if we both try to steal. By choosing "Share," I am maximizing the benefit for the group. If my partner is also thinking logically and recognizes that mutual cooperation is the only way to guarantee a positive outcome for both of us, we both walk away with $1,000.
#
# Ultimately, this is a version of the Prisoner's Dilemma, and cooperation is the choice that leads to the most stable and beneficial long-term result.

# %%
response_groq = groq_client.chat.completions.create(
  model="openai/gpt-oss-120b",
  messages=dilemma,
)
display(Markdown(response_groq.choices[0].message.content))
# Out:
# I’d choose **Share**.
#
# Even though “Steal” offers a tempting $2,000 if the other player cooperates, the risk of both players stealing (leaving both of us with nothing) makes the guaranteed $1,000 from mutual sharing the safer, more reliable outcome. In a one‑shot game with no way to coordinate or enforce trust, picking “Share” ensures at least a positive payoff for both contestants.

# %%
response = groq_client.chat.completions.create(
  model="qwen/qwen3.8-27b",
  messages=dilemma,
)
display(Markdown(response.choices[0].message.content))
# Out:
# I choose to **Share**.
#
# ### Reasoning:
# 1. **Cooperation Benefit**: If my partner also chooses "Share," we both walk away with $1,000. This is the best collective outcome (total pool: $2,000).
# 2. **Risk Assessment**:
#    - If I choose "Steal" and they "Share," I get $2,000, but they get $0. This creates a winner and a loser.
#    - If I choose "Steal" and they "Steal," we both get $0.
#    - If I choose "Share" and they "Steal," I get $0, and they get $2,000.
# 3. **Game Show Context**: In many real-world iterations of this game (like *Golden Balls* on the BBC or similar shows), opting to "Share" when the other player is also cooperative builds trust and rewards fairness. While "Steal" offers a higher individual maximum ($2,000), it only pays off if the other player is predictable and cooperative. Choosing "Share" signals a commitment to mutual gain, which is the most rational strategy if you believe your partner is also rational and values cooperative outcomes.
#
# ...
