# %%
import os
from dotenv import load_dotenv

load_dotenv(override=True)
api_key = os.getenv('GROQ_API_KEY')

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("gsk_"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
import requests

headers = {"Authorization": f"Bearer {api_key}", "Content-Type": "application/json"}

payload = {
    "model": "openai/gpt-oss-20b",
    "messages": [
        {"role": "user", "content": "Tell me a fun fact"}]
}

payload
# Out:
# {'model': 'openai/gpt-oss-20b',
#  'messages': [{'role': 'user', 'content': 'Tell me a fun fact'}]}

# %%
response = requests.post(
    "https://api.groq.com/openai/v1/chat/completions",
    headers=headers,
    json=payload
)

response.json()
# Out:
# {'id': 'chatcmpl-cbd0fbfb-382c-4880-9ce2-0ba1a3984717',
#  'object': 'chat.completion',
#  'created': 1789685400,
#  'model': 'openai/gpt-oss-20b',
#  'choices': [{'index': 0,
#    'message': {'role': 'assistant',
#     'content': 'Did you know that honey never spoils? Archaeologists have found pots of perfectly edible honey in ancient Egyptian tombs that are over 3,000\u202fyears old—thanks to its natural acidity and low water content, it stays safe from bacteria for millennia. 🍯',
#     'reasoning': 'User: "Tell me a fun fact". Provide a fun fact. No constraints. Probably short and interesting. Let\'s produce a fun fact: e.g., honey never spoils. Or octopus has 3 hearts. Or something about brain. Let\'s pick something surprising. Provide a short answer.'},
#    'logprobs': None,
#    'finish_reason': 'stop'}],
#  'usage': {'queue_time': 0.314599741,
#   'prompt_tokens': 76,
#   'prompt_time': 0.003697817,
#   'completion_tokens': 124,
#   'completion_time': 0.125108274,
#   'total_tokens': 200,
#   'total_time': 0.128806091,
#   'completion_tokens_details': {'reasoning_tokens': 60}},
#  'usage_breakdown': None,
#  'system_fingerprint': 'fp_d3e146e1a5',
#  'x_groq': {'id': 'req_01m2rs009neszrwqvg4d5zmz0k', 'seed': 259130075},
#  'service_tier': 'on_demand'}

# %%
response.json()["choices"][0]["message"]["content"]
# Out:
# 'Did you know that honey never spoils? Archaeologists have found pots of perfectly edible honey in ancient Egyptian tombs that are over 3,000\u202fyears old—thanks to its natural acidity and low water content, it stays safe from bacteria for millennia. 🍯'

# %%
# Create OpenAI client

from openai import OpenAI
openai = OpenAI(
  api_key=os.getenv("GROQ_API_KEY"),
  base_url="https://api.groq.com/openai/v1"
)

response = openai.chat.completions.create(model="openai/gpt-oss-20b", messages=[{"role": "user", "content": "Tell me a fun fact"}])

response.choices[0].message.content
# Out:
# 'Did you know that honey never spoils? Archaeologists have found pots of honey in ancient Egyptian tombs that are over 3,000 years old—and they’re still perfectly edible! The natural composition of honey (low water content and acidic pH) creates an inhospitable environment for bacteria and microorganisms, allowing it to preserve indefinitely. 🍯🌟'

# %% [markdown]
# Google Gemini

# %%
GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"

load_dotenv(override=True)

google_api_key = os.getenv("GOOGLE_API_KEY")

if not google_api_key:
    print("No API key was found - please be sure to add your key to the .env file, and save the file! Or you can skip the next 2 cells if you don't want to use Gemini")
elif not google_api_key.startswith(("AIz", "AQ.")):
    print("An API key was found, but it doesn't start with AIz or AQ.")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
gemini = OpenAI(base_url=GEMINI_BASE_URL, api_key=google_api_key)

response = gemini.chat.completions.create(model="gemini-3.1-flash-lite", messages=[{"role": "user", "content": "Tell me a fun fact"}])

response.choices[0].message.content
# Out:
# 'A fun fact for you: **Sea otters hold hands when they sleep so they don’t drift apart.**\n\nThey often sleep in groups called "rafts" and will wrap themselves in long strands of giant kelp, which acts like an anchor to keep them in one place while they snooze. If there isn\'t any kelp nearby, they’ll link paws to stay tethered to their friends!'

# %% [markdown]
# Ollama

# %%
requests.get("http://localhost:11434").content
# Out:
# b'Ollama is running'

# %%
# !ollama pull gemma3:270m
# Out:
# ]11;?\pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest
# pulling 735af2139dc6: 100% ▕██████████████████▏ 291 MB
# pulling 4b19ac7dd2fb: 100% ▕██████████████████▏  476 B
# pulling 3e2c24001f9e: 100% ▕██████████████████▏ 8.4 KB
# pulling 339e884a40f6: 100% ▕██████████████████▏   61 B
# pulling 74156d92caf6: 100% ▕██████████████████▏  490 B
# verifying sha256 digest
# writing manifest
# success

# %%
OLLAMA_BASE_URL = "http://localhost:11434/v1"

ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')

# %%
# Get a fun fact

response = ollama.chat.completions.create(model="gemma3:270m", messages=[{"role": "user", "content": "Tell me a fun fact"}])

response.choices[0].message.content
# Out:
# "Okay, here's a fun fact:\n"
